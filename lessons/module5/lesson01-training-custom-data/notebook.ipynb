# %% [markdown]
# # Lesson 01: Training Diffusion LMs on Custom Data
#
# In this notebook, you will learn how to take any text dataset and train a diffusion language model on it. We cover the complete pipeline: data preprocessing, model configuration, training with monitoring, and sample generation.
#
# **Compute Note**: This notebook can run on CPU for the small demo dataset. For real-world datasets, a GPU is strongly recommended.
